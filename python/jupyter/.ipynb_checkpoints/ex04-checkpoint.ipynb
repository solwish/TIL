# %% [markdown]
# ## 인터넷 상의 데이터 읽기
#
# + URL상의 CSV 읽기
#  - Pandas.read_csv(url)
#
# + 직접 크롤링
#  - requests/Selenium 라이브러리를 통한 처리
#  - pandas.read_html(url, ...) : 내부적으로 requests 라이브러리 활용
# + pandas-datareader 라이브러리
#  - 내부적으로 requests 라이브러리 활용
#  - 지원 데이터 소스 : FRED, Nasdaq, Yahoo Fianace, Google Finance 등
#  - 정식 API가 아닌 크롤링을 사용하는 것이기에 버전에 따라 오류 발생 가능
# + seaborn 라이브러리
#  - 예제용 저장소 : https://github.com/mwaskom/seaborn-data
#  - 깃헙에서 raw url로 입력해야 함

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/raw/mpg.csv', index_col='name')
print(df.shape)
df.head()
# Out:
# (398, 8)
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1

# %%
df.loc['subaru']
# Out:
#          mpg  cylinders  displacement horsepower  weight  acceleration  \
# name
# subaru  26.0          4         108.0         93    2391          15.5
# subaru  32.3          4          97.0         67    2065          17.8
#
#         model_year  origin
# name
# subaru          74       3
# subaru          81       3

# %% [markdown]
# # pandas.read_html
# + 웹페이지 크롤링을 쉽게 도와주는 라이브러리 / table tag로 자료가 돠어있는경우 가능
# + 디도스 put에 대한 보안처리되어있는경우 안될 수 있음
# + table 외에 다른 문자열이 있을경우 곤란

# %%
df_list = pd.read_html('http://astro.kasi.re.kr/life/pageView/5', encoding='utf-8') #encoding='cp949'
df_list
# Out:
# [                양력          음력                     음력간지
#  0   2020-03-01 (일)  2020-02-07  경자(庚子)년 기묘(己卯)월 계묘(癸卯)일
#  1   2020-03-02 (월)  2020-02-08  경자(庚子)년 기묘(己卯)월 갑진(甲辰)일
#  2   2020-03-03 (화)  2020-02-09  경자(庚子)년 기묘(己卯)월 을사(乙巳)일
#  3   2020-03-04 (수)  2020-02-10  경자(庚子)년 기묘(己卯)월 병오(丙午)일
#  4   2020-03-05 (목)  2020-02-11  경자(庚子)년 기묘(己卯)월 정미(丁未)일
#  5   2020-03-06 (금)  2020-02-12  경자(庚子)년 기묘(己卯)월 무신(戊申)일
#  6   2020-03-07 (토)  2020-02-13  경자(庚子)년 기묘(己卯)월 기유(己酉)일
#  7   2020-03-08 (일)  2020-02-14  경자(庚子)년 기묘(己卯)월 경술(庚戌)일
#  8   2020-03-09 (월)  2020-02-15  경자(庚子)년 기묘(己卯)월 신해(辛亥)일
#  9   2020-03-10 (화)  2020-02-16  경자(庚子)년 기묘(己卯)월 임자(壬子)일
#  10  2020-03-11 (수)  2020-02-17  경자(庚子)년 기묘(己卯)월 계축(癸丑)일
#  11  2020-03-12 (목)  2020-02-18  경자(庚子)년 기묘(己卯)월 갑인(甲寅)일
#  12  2020-03-13 (금)  2020-02-19  경자(庚子)년 기묘(己卯)월 을묘(乙卯)일
#  13  2020-03-14 (토)  2020-02-20  경자(庚子)년 기묘(己卯)월 병진(丙辰)일
#  14  2020-03-15 (일)  2020-02-21  경자(庚子)년 기묘(己卯)월 정사(丁巳)일
# ...

# %%
len(df_list)  # 현 상태는 1개의 데이터
# Out:
# 1

# %%
df = df_list[0]

# %%
print(df.shape)
df.head()
# Out:
# (31, 3)
#                양력          음력                     음력간지
# 0  2020-03-01 (일)  2020-02-07  경자(庚子)년 기묘(己卯)월 계묘(癸卯)일
# 1  2020-03-02 (월)  2020-02-08  경자(庚子)년 기묘(己卯)월 갑진(甲辰)일
# 2  2020-03-03 (화)  2020-02-09  경자(庚子)년 기묘(己卯)월 을사(乙巳)일
# 3  2020-03-04 (수)  2020-02-10  경자(庚子)년 기묘(己卯)월 병오(丙午)일
# 4  2020-03-05 (목)  2020-02-11  경자(庚子)년 기묘(己卯)월 정미(丁未)일

# %% [markdown]
# # Pandas-datareader
# + 쉘에서 pip install --upgrade pandas-datareader 입력

# %%
import pandas_datareader as pdr

# %%
pdr.get_data_yahoo('035420.KS', '2018-01-01')
# Out:
#                 High       Low      Open     Close    Volume      Adj Close
# Date
# 2018-01-03  176800.0  172800.0  175200.0  174200.0  423950.0  173740.343750
# 2018-01-04  179400.0  174600.0  175800.0  178600.0  650560.0  178128.734375
# 2018-01-05  183600.0  176000.0  178600.0  181600.0  684055.0  181120.828125
# 2018-01-08  190600.0  181600.0  183000.0  190000.0  981690.0  189498.656250
# 2018-01-09  190400.0  186600.0  188800.0  188800.0  390135.0  188301.828125
# 2018-01-10  195000.0  185400.0  188600.0  185600.0  600485.0  185110.265625
# 2018-01-11  186800.0  181800.0  185600.0  183400.0  469270.0  182916.078125
# 2018-01-12  186000.0  180200.0  184000.0  181800.0  447070.0  181320.296875
# 2018-01-15  185000.0  182200.0  183400.0  184200.0  296000.0  183713.968750
# 2018-01-16  184800.0  178600.0  183800.0  180600.0  476510.0  180123.468750
# 2018-01-17  181200.0  177600.0  180600.0  177600.0  535130.0  177131.375000
# ...
